# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Data of Gender is converted into Binary Data
df_one = pd.get_dummies(df["Attrition"])
df_one
# Out:
#       No  Yes
# 0      0    1
# 1      1    0
# 2      0    1
# 3      1    0
# 4      1    0
# ...   ..  ...
# 1465   1    0
# 1466   1    0
# 1467   1    0
# 1468   1    0
# 1469   1    0
#
# [1470 rows x 2 columns]

# %%
# Binary Data is Concatenated into Dataframe
df_two = pd.concat((df_one, df), axis=1)
 
 
# We want Male =0 and Female =1 So we drop Male column here
df_two = df_two.drop(["No"], axis=1)
df_Att = df_two.rename({"Yes":"Attrition_status"}, axis =1)

# Drop columns that are not useful
df_Att.drop(["EmployeeCount"], axis=1, inplace = True)
df_Att.drop(["Over18"], axis=1, inplace = True)
df_Att.drop(["StandardHours"], axis=1, inplace = True)
df_Att
# Out:
#       Attrition_status  Age Attrition     BusinessTravel  DailyRate  \
# 0                    1   41       Yes      Travel_Rarely       1102
# 1                    0   49        No  Travel_Frequently        279
# 2                    1   37       Yes      Travel_Rarely       1373
# 3                    0   33        No  Travel_Frequently       1392
# 4                    0   27        No      Travel_Rarely        591
# ...                ...  ...       ...                ...        ...
# 1465                 0   36        No  Travel_Frequently        884
# 1466                 0   39        No      Travel_Rarely        613
# 1467                 0   27        No      Travel_Rarely        155
# 1468                 0   49        No  Travel_Frequently       1023
# 1469                 0   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeNumber  ...  PerformanceRating RelationshipSatisfaction  \
# 0                  1  ...                  3                        1
# 1                  2  ...                  4                        4
# 2                  4  ...                  3                        2
# 3                  5  ...                  3                        3
# 4                  7  ...                  3                        4
# ...              ...  ...                ...                      ...
# 1465            2061  ...                  3                        3
# 1466            2062  ...                  3                        1
# 1467            2064  ...                  4                        2
# 1468            2065  ...                  3                        4
# 1469            2068  ...                  3                        1
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 33 columns]

# %%
df_Att.drop(["EmployeeNumber"], axis=1, inplace = True)

# %%
df_Att
# Out:
#       Attrition_status  Age Attrition     BusinessTravel  DailyRate  \
# 0                    1   41       Yes      Travel_Rarely       1102
# 1                    0   49        No  Travel_Frequently        279
# 2                    1   37       Yes      Travel_Rarely       1373
# 3                    0   33        No  Travel_Frequently       1392
# 4                    0   27        No      Travel_Rarely        591
# ...                ...  ...       ...                ...        ...
# 1465                 0   36        No  Travel_Frequently        884
# 1466                 0   39        No      Travel_Rarely        613
# 1467                 0   27        No      Travel_Rarely        155
# 1468                 0   49        No  Travel_Frequently       1023
# 1469                 0   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EnvironmentSatisfaction  ... PerformanceRating  \
# 0                           2  ...                 3
# 1                           3  ...                 4
# 2                           4  ...                 3
# 3                           4  ...                 3
# 4                           1  ...                 3
# ...                       ...  ...               ...
# 1465                        3  ...                 3
# 1466                        4  ...                 3
# 1467                        2  ...                 4
# 1468                        4  ...                 3
# 1469                        2  ...                 3
#
#       RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                            1                 0                  8
# 1                            4                 1                 10
# 2                            2                 0                  7
# 3                            3                 0                  8
# 4                            4                 1                  6
# ...                        ...               ...                ...
# 1465                         3                 1                 17
# 1466                         1                 1                  9
# 1467                         2                 1                  6
# 1468                         4                 0                 17
# 1469                         1                 0                  6
#
#      TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0                        0                1              6
# 1                        3                3             10
# 2                        3                3              0
# 3                        3                3              8
# 4                        3                3              2
# ...                    ...              ...            ...
# 1465                     3                3              5
# 1466                     5                3              7
# 1467                     0                3              6
# 1468                     3                2              9
# 1469                     3                4              4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                      4                        0                     5
# 1                      7                        1                     7
# 2                      0                        0                     0
# 3                      7                        3                     0
# 4                      2                        2                     2
# ...                  ...                      ...                   ...
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
# [1470 rows x 32 columns]

# %%
corr_matrix = df_Att.corr().abs()

#the matrix is symmetric so we need to extract upper triangle matrix without diagonal (k = 1)
# Decending order 
sol = (corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
                  .stack()
                  .sort_values(ascending=False))

#first element of sol series is the pair with the biggest correlation

# %%
corrdf = sol.to_frame()
corrdf.rename(columns = {0:'Corr_coefficient'}, inplace = True)
corrdf.sort_values(by = "Corr_coefficient", ascending = False)
# Out:
#                                                Corr_coefficient
# JobLevel                 MonthlyIncome                 0.950300
#                          TotalWorkingYears             0.782208
# PercentSalaryHike        PerformanceRating             0.773550
# MonthlyIncome            TotalWorkingYears             0.772893
# YearsAtCompany           YearsWithCurrManager          0.769212
# ...                                                         ...
# EnvironmentSatisfaction  JobLevel                      0.001212
# TotalWorkingYears        WorkLifeBalance               0.001008
# RelationshipSatisfaction YearsWithCurrManager          0.000867
# JobSatisfaction          MonthlyRate                   0.000644
# DailyRate                PerformanceRating             0.000473
#
# [276 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df_Att.corr())

plt.savefig("Plotting_Correlation_HeatMap.jpg")

# %%
df_Att.drop(["JobLevel"], axis=1, inplace = True)
df_Att.drop(["Attrition"], axis=1, inplace = True)
df_Att
# Out:
#       Attrition_status  Age     BusinessTravel  DailyRate  \
# 0                    1   41      Travel_Rarely       1102
# 1                    0   49  Travel_Frequently        279
# 2                    1   37      Travel_Rarely       1373
# 3                    0   33  Travel_Frequently       1392
# 4                    0   27      Travel_Rarely        591
# ...                ...  ...                ...        ...
# 1465                 0   36  Travel_Frequently        884
# 1466                 0   39      Travel_Rarely        613
# 1467                 0   27      Travel_Rarely        155
# 1468                 0   49  Travel_Frequently       1023
# 1469                 0   34      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EnvironmentSatisfaction  Gender  ...  PerformanceRating  \
# 0                           2  Female  ...                  3
# 1                           3    Male  ...                  4
# 2                           4    Male  ...                  3
# 3                           4  Female  ...                  3
# 4                           1    Male  ...                  3
# ...                       ...     ...  ...                ...
# 1465                        3    Male  ...                  3
# 1466                        4    Male  ...                  3
# 1467                        2    Male  ...                  4
# 1468                        4    Male  ...                  3
# 1469                        2    Male  ...                  3
#
#       RelationshipSatisfaction StockOptionLevel  TotalWorkingYears  \
# 0                            1                0                  8
# 1                            4                1                 10
# 2                            2                0                  7
# 3                            3                0                  8
# 4                            4                1                  6
# ...                        ...              ...                ...
# 1465                         3                1                 17
# 1466                         1                1                  9
# 1467                         2                1                  6
# 1468                         4                0                 17
# 1469                         1                0                  6
#
#      TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                        0                1               6
# 1                        3                3              10
# 2                        3                3               0
# 3                        3                3               8
# 4                        3                3               2
# ...                    ...              ...             ...
# 1465                     3                3               5
# 1466                     5                3               7
# 1467                     0                3               6
# 1468                     3                2               9
# 1469                     3                4               4
#
#       YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0                      4                       0                     5
# 1                      7                       1                     7
# 2                      0                       0                     0
# 3                      7                       3                     0
# 4                      2                       2                     2
# ...                  ...                     ...                   ...
# 1465                   2                       0                     3
# 1466                   7                       1                     7
# 1467                   2                       0                     3
# 1468                   6                       0                     8
# 1469                   3                       1                     2
#
# [1470 rows x 30 columns]

# %%
def Under30 (row):
    if row['Age'] < 30 :
        return "Under 30"
    else:
        return "Above 30"

# %%
df_Att["Below 30"] = df.apply(lambda row: Under30(row), axis=1)
df_Att
# Out:
#       Attrition_status  Age     BusinessTravel  DailyRate  \
# 0                    1   41      Travel_Rarely       1102
# 1                    0   49  Travel_Frequently        279
# 2                    1   37      Travel_Rarely       1373
# 3                    0   33  Travel_Frequently       1392
# 4                    0   27      Travel_Rarely        591
# ...                ...  ...                ...        ...
# 1465                 0   36  Travel_Frequently        884
# 1466                 0   39      Travel_Rarely        613
# 1467                 0   27      Travel_Rarely        155
# 1468                 0   49  Travel_Frequently       1023
# 1469                 0   34      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EnvironmentSatisfaction  Gender  ...  RelationshipSatisfaction  \
# 0                           2  Female  ...                         1
# 1                           3    Male  ...                         4
# 2                           4    Male  ...                         2
# 3                           4  Female  ...                         3
# 4                           1    Male  ...                         4
# ...                       ...     ...  ...                       ...
# 1465                        3    Male  ...                         3
# 1466                        4    Male  ...                         1
# 1467                        2    Male  ...                         2
# 1468                        4    Male  ...                         4
# 1469                        2    Male  ...                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                 8                      0
# 1                    1                10                      3
# 2                    0                 7                      3
# 3                    0                 8                      3
# 4                    1                 6                      3
# ...                ...               ...                    ...
# 1465                 1                17                      3
# 1466                 1                 9                      5
# 1467                 1                 6                      0
# 1468                 0                17                      3
# 1469                 0                 6                      3
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                  1               6                   4
# 1                  3              10                   7
# 2                  3               0                   0
# 3                  3               8                   7
# 4                  3               2                   2
# ...              ...             ...                 ...
# 1465               3               5                   2
# 1466               3               7                   7
# 1467               3               6                   2
# 1468               2               9                   6
# 1469               4               4                   3
#
#       YearsSinceLastPromotion YearsWithCurrManager  Below 30
# 0                           0                    5  Above 30
# 1                           1                    7  Above 30
# 2                           0                    0  Above 30
# 3                           3                    0  Above 30
# 4                           2                    2  Under 30
# ...                       ...                  ...       ...
# 1465                        0                    3  Above 30
# 1466                        1                    7  Above 30
# 1467                        0                    3  Under 30
# 1468                        0                    8  Above 30
# 1469                        1                    2  Above 30
#
# [1470 rows x 31 columns]

# %%
fig, ax = plt.subplots()
df_Att['WorkLifeBalance'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_Att['Attrition_status'].value_counts().plot(kind='barh', title="Attrition Distribution")
savefig("Attrition Distribution.jpg")

# %%
df_Att['Below 30'].value_counts().plot(kind='bar', title="Age Distribution", color = "green")
plt.savefig("Age Distribution.jpg")

# %%
# There are 23 numerical columns in the data, and 6 categorical data. 
df_Att.describe()
# Out:
#        Attrition_status          Age    DailyRate  DistanceFromHome  \
# count       1470.000000  1470.000000  1470.000000       1470.000000
# mean           0.161224    36.923810   802.485714          9.192517
# std            0.367863     9.135373   403.509100          8.106864
# min            0.000000    18.000000   102.000000          1.000000
# 25%            0.000000    30.000000   465.000000          2.000000
# 50%            0.000000    36.000000   802.000000          7.000000
# 75%            0.000000    43.000000  1157.000000         14.000000
# max            1.000000    60.000000  1499.000000         29.000000
#
#          Education  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count  1470.000000              1470.000000  1470.000000     1470.000000
# mean      2.912925                 2.721769    65.891156        2.729932
# std       1.024165                 1.093082    20.329428        0.711561
# min       1.000000                 1.000000    30.000000        1.000000
# 25%       2.000000                 2.000000    48.000000        2.000000
# 50%       3.000000                 3.000000    66.000000        3.000000
# 75%       4.000000                 4.000000    83.750000        3.000000
# max       5.000000                 4.000000   100.000000        4.000000
#
#        JobSatisfaction  MonthlyIncome  ...  PerformanceRating  \
# count      1470.000000    1470.000000  ...        1470.000000
# mean          2.728571    6502.931293  ...           3.153741
# std           1.102846    4707.956783  ...           0.360824
# min           1.000000    1009.000000  ...           3.000000
# 25%           2.000000    2911.000000  ...           3.000000
# 50%           3.000000    4919.000000  ...           3.000000
# 75%           4.000000    8379.000000  ...           3.000000
# max           4.000000   19999.000000  ...           4.000000
#
#        RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# count               1470.000000       1470.000000        1470.000000
# mean                   2.712245          0.793878          11.279592
# std                    1.081209          0.852077           7.780782
# min                    1.000000          0.000000           0.000000
# 25%                    2.000000          0.000000           6.000000
# 50%                    3.000000          1.000000          10.000000
# 75%                    4.000000          1.000000          15.000000
# max                    4.000000          3.000000          40.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            1470.000000      1470.000000     1470.000000
# mean                2.799320         2.761224        7.008163
# std                 1.289271         0.706476        6.126525
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        3.000000
# 50%                 3.000000         3.000000        5.000000
# 75%                 3.000000         3.000000        9.000000
# max                 6.000000         4.000000       40.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count         1470.000000              1470.000000           1470.000000
# mean             4.229252                 2.187755              4.123129
# std              3.623137                 3.222430              3.568136
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              3.000000                 1.000000              3.000000
# 75%              7.000000                 3.000000              7.000000
# max             18.000000                15.000000             17.000000
#
# [8 rows x 23 columns]

# %%
# 1. build one linear bin and charts
# 2. Make a for loop
# use a stacked plot to include all the information.

# %%
lineardf = pd.DataFrame()
lineardf["attrition"] = df_Att["Attrition_status"]
lineardf["age"] = df_Att["Age"]

# %%
lineardf["age"].max() - lineardf["age"].min()
# Out:
# 42

# %%
lineardf['bin'] = pd.qcut(lineardf['age'], q=4, labels=[0,1,2,3])

# %%
import matplotlib.pyplot as plt

# %%
lineardf.sort_values(by = "age", ascending = False)
# Out:
#       attrition  age bin
# 1209          0   60   3
# 427           0   60   3
# 536           0   60   3
# 411           0   60   3
# 879           0   60   3
# ...         ...  ...  ..
# 972           0   18   0
# 457           1   18   0
# 828           1   18   0
# 1153          1   18   0
# 301           0   18   0
#
# [1470 rows x 3 columns]

# %%
df_pivot = lineardf.groupby(['bin', 'attrition']).count().reset_index().pivot(columns=['attrition'], index='bin')
df_pivot.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='bin'>

# %%
IndependOnlydf = df_Att.drop("Attrition_status", axis = 1)

# %%
#IndependOnlydf.columns
IndependOnlydf = IndependOnlydf.select_dtypes(include=np.number, exclude=None)

# %%
IndependOnlydf
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      41       1102                 1          2                        2
# 1      49        279                 8          1                        3
# 2      37       1373                 2          2                        4
# 3      33       1392                 3          4                        4
# 4      27        591                 2          1                        1
# ...   ...        ...               ...        ...                      ...
# 1465   36        884                23          2                        3
# 1466   39        613                 6          1                        4
# 1467   27        155                 4          3                        2
# 1468   49       1023                 2          3                        4
# 1469   34        628                 8          3                        2
#
#       HourlyRate  JobInvolvement  JobSatisfaction  MonthlyIncome  MonthlyRate  \
# 0             94               3                4           5993        19479
# 1             61               2                2           5130        24907
# 2             92               2                3           2090         2396
# 3             56               3                3           2909        23159
# 4             40               3                2           3468        16632
# ...          ...             ...              ...            ...          ...
# 1465          41               4                4           2571        12290
# 1466          42               2                1           9991        21457
# 1467          87               4                2           6142         5174
# 1468          63               2                2           5390        13243
# 1469          82               4                3           4404        10228
#
#       ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0     ...                  3                         1                 0
# 1     ...                  4                         4                 1
# 2     ...                  3                         2                 0
# 3     ...                  3                         3                 0
# 4     ...                  3                         4                 1
# ...   ...                ...                       ...               ...
# 1465  ...                  3                         3                 1
# 1466  ...                  3                         1                 1
# 1467  ...                  4                         2                 1
# 1468  ...                  3                         4                 0
# 1469  ...                  3                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 22 columns]

# %%
for col in IndependOnlydf.columns:
    newdf = pd.DataFrame()
    newdf["attrition"] = df_Att['Attrition_status']
    newdf[col] = IndependOnlydf[col]
    newdf['bin'] = pd.qcut(newdf[col], q=5, duplicates = "drop")
    df_pivot = newdf.groupby(['bin', 'attrition']).count().reset_index().pivot(columns=['attrition'], index='bin')
    df_pivot.plot(kind='bar', stacked=True, title= col)
    #plt.savefig(col + '.jpg')

# %%
import cv2
import os

# %%
# create figure
fig = plt.figure(figsize=(10, 7))
  
# setting values to rows and column variables
rows = 7
columns = 3

directory = 'Linear Plots'
 
# iterate over files in
# that directory
pltlist = []
for filename in os.listdir(directory):
    file = cv2.imread(filename)
    pltlist.append(file)
# Out:
# [ WARN:0@287.601] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('PercentSalaryHike.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.604] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('MonthlyRate.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.604] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('RelationshipSatisfaction.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.604] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('WorkLifeBalance.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.604] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('TrainingTimesLastYear.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.604] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('NumCompaniesWorked.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.604] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('HourlyRate.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.604] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('TotalWorkingYears.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.604] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('DailyRate.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.604] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('JobInvolvement.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('MonthlyIncome.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('YearsSinceLastPromotion.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('EnvironmentSatisfaction.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('DistanceFromHome.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('YearsInCurrentRole.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('StockOptionLevel.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('Education.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('YearsWithCurrManager.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('JobSatisfaction.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('YearsAtCompany.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@287.605] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('Age.jpg'): can't open/read file: check file path/integrity

# %%
type(pltlist[0])
# Out:
# NoneType
